# %% [markdown]
# <a href="https://colab.research.google.com/github/MiaKuntz/machine_learning_2/blob/main/ML4BI_E6_solution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Machine Learning for BI 2
#
# ## Deep Learning exercises for week 5
#
# In this exercise, you'll expand on last weeks exercise by adding pre-trained models to the mix. In particular, you'll work with ResNet50, a powerful pre-trained model.

# %% [markdown]
# Here is the task: Try a ResNet50 with data augmentation on the cifar10 dataset.
#
# Two tips:
#
#
#
# 1.   Remember to turn on the GPU. Don't let it stand idle. Whenever you need to take a break, remember to switch it off.
# 2.   When preprocessing the model, do this to avoid errors
#
# ```
# # Apply the preprocess_input function
# x = Lambda(preprocess_input)(x)
# ```
#
# This allows arbitrary expressions to be inserted into Keras models.

# %% [markdown]
# ## Using a pre-trained ResNet50 model
#
# **Load libraries**

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Input, Lambda, Layer
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers
from tensorflow.keras.applications.resnet50 import preprocess_input

# %% [markdown]
# **Load data**

# %%
# Load CIFAR-10 data
(x_train, y_train), (x_test, y_test) = keras.datasets.cifar10.load_data()

# Convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, 10)
y_test = keras.utils.to_categorical(y_test, 10)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 3s 0us/step

# %% [markdown]
# **Model building**

# %%
data_augmentation = keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.2),
])

# %%
# Make sure you define the 'base_model' after the augmentation and normalization
# Ensure the 'input_tensor' argument in ResNet50 is replaced with 'input_shape'
# if you are defining 'x' as the output of previous layers
base_model = keras.applications.ResNet50(include_top=False,
                                         weights='imagenet',
                                         input_shape=(32, 32, 3))
base_model.trainable = False

# Define the input tensor for your model
input_tensor = Input(shape=(32, 32, 3))

# Apply data augmentation to the inputs
x = data_augmentation(input_tensor)

# Apply the preprocess_input function
x = Lambda(preprocess_input)(x)

# Add custom layers on top of the base model
x = base_model(x)
x = GlobalAveragePooling2D()(x)
x = layers.Dense(256, activation='relu')(x)
x = layers.Dropout(0.5)(x)
predictions = Dense(10, activation='softmax')(x)

# Create the final model
model = Model(inputs=input_tensor, outputs=predictions)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 1s 0us/step

# %% [markdown]
# **Compile**

# %%
model.compile(optimizer="Adam", loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# **Train**

# %%
callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="resnet50.keras",
        save_best_only=True,
        monitor="val_loss")
]

# %%
history = model.fit(x_train, y_train,
                    epochs=40,
                    batch_size=256,
                    validation_split=0.2,  # Use 20% of the data for validation
                    callbacks=callbacks,  # Include the callbacks in training
                    verbose=1)
# Out:
# Epoch 1/40
# 157/157 [==============================] - 16s 47ms/step - loss: 1.8180 - accuracy: 0.4125 - val_loss: 1.1755 - val_accuracy: 0.5904
# Epoch 2/40
# 157/157 [==============================] - 5s 34ms/step - loss: 1.4185 - accuracy: 0.5030 - val_loss: 1.1073 - val_accuracy: 0.6140
# Epoch 3/40
# 157/157 [==============================] - 5s 33ms/step - loss: 1.3496 - accuracy: 0.5228 - val_loss: 1.0833 - val_accuracy: 0.6230
# Epoch 4/40
# 157/157 [==============================] - 6s 36ms/step - loss: 1.3109 - accuracy: 0.5396 - val_loss: 1.0695 - val_accuracy: 0.6274
# Epoch 5/40
# 157/157 [==============================] - 5s 32ms/step - loss: 1.2799 - accuracy: 0.5487 - val_loss: 1.0464 - val_accuracy: 0.6324
# Epoch 6/40
# 157/157 [==============================] - 5s 32ms/step - loss: 1.2584 - accuracy: 0.5590 - val_loss: 1.0293 - val_accuracy: 0.6420
# Epoch 7/40
# 157/157 [==============================] - 4s 27ms/step - loss: 1.2363 - accuracy: 0.5666 - val_loss: 1.0414 - val_accuracy: 0.6403
# Epoch 8/40
# 157/157 [==============================] - 5s 34ms/step - loss: 1.2215 - accuracy: 0.5678 - val_loss: 1.0006 - val_accuracy: 0.6515
# Epoch 9/40
# 157/157 [==============================] - 4s 26ms/step - loss: 1.2023 - accuracy: 0.5762 - val_loss: 1.0067 - val_accuracy: 0.6494
# Epoch 10/40
# 157/157 [==============================] - 4s 26ms/step - loss: 1.2004 - accuracy: 0.5777 - val_loss: 1.0034 - val_accuracy: 0.6471
# Epoch 11/40
# 157/157 [==============================] - 4s 26ms/step - loss: 1.1902 - accuracy: 0.5799 - val_loss: 1.0011 - val_accuracy: 0.6532
# Epoch 12/40
# 157/157 [==============================] - 5s 34ms/step - loss: 1.1758 - accuracy: 0.5863 - val_loss: 0.9896 - val_accuracy: 0.6512
# Epoch 13/40
# 157/157 [==============================] - 5s 32ms/step - loss: 1.1677 - accuracy: 0.5903 - val_loss: 0.9738 - val_accuracy: 0.6618
# Epoch 14/40
# 157/157 [==============================] - 4s 25ms/step - loss: 1.1655 - accuracy: 0.5904 - val_loss: 0.9766 - val_accuracy: 0.6602
# Epoch 15/40
# 157/157 [==============================] - 5s 35ms/step - loss: 1.1502 - accuracy: 0.5939 - val_loss: 0.9712 - val_accuracy: 0.6605
# Epoch 16/40
# 157/157 [==============================] - 4s 26ms/step - loss: 1.1526 - accuracy: 0.5948 - val_loss: 0.9754 - val_accuracy: 0.6621
# Epoch 17/40
# 157/157 [==============================] - 5s 29ms/step - loss: 1.1375 - accuracy: 0.5997 - val_loss: 0.9809 - val_accuracy: 0.6538
# Epoch 18/40
# 157/157 [==============================] - 4s 26ms/step - loss: 1.1377 - accuracy: 0.5984 - val_loss: 0.9746 - val_accuracy: 0.6564
# Epoch 19/40
# 157/157 [==============================] - 4s 25ms/step - loss: 1.1347 - accuracy: 0.5986 - val_loss: 0.9789 - val_accuracy: 0.6594
# Epoch 20/40
# 157/157 [==============================] - 5s 34ms/step - loss: 1.1386 - accuracy: 0.5997 - val_loss: 0.9646 - val_accuracy: 0.6648
# Epoch 21/40
# 157/157 [==============================] - 5s 32ms/step - loss: 1.1208 - accuracy: 0.6051 - val_loss: 0.9537 - val_accuracy: 0.6638
# Epoch 22/40
# 157/157 [==============================] - 4s 26ms/step - loss: 1.1138 - accuracy: 0.6058 - val_loss: 0.9600 - val_accuracy: 0.6659
# Epoch 23/40
# 157/157 [==============================] - 4s 27ms/step - loss: 1.1198 - accuracy: 0.6059 - val_loss: 0.9715 - val_accuracy: 0.6618
# Epoch 24/40
# 157/157 [==============================] - 4s 26ms/step - loss: 1.1121 - accuracy: 0.6090 - val_loss: 0.9733 - val_accuracy: 0.6612
# Epoch 25/40
# 157/157 [==============================] - 4s 26ms/step - loss: 1.1107 - accuracy: 0.6076 - val_loss: 0.9674 - val_accuracy: 0.6656
# Epoch 26/40
# 157/157 [==============================] - 4s 26ms/step - loss: 1.1070 - accuracy: 0.6107 - val_loss: 0.9657 - val_accuracy: 0.6637
# Epoch 27/40
# 157/157 [==============================] - 4s 25ms/step - loss: 1.1017 - accuracy: 0.6129 - val_loss: 0.9581 - val_accuracy: 0.6658
# Epoch 28/40
# 157/157 [==============================] - 4s 26ms/step - loss: 1.1051 - accuracy: 0.6099 - val_loss: 0.9596 - val_accuracy: 0.6664
# Epoch 29/40
# 157/157 [==============================] - 5s 34ms/step - loss: 1.0909 - accuracy: 0.6168 - val_loss: 0.9511 - val_accuracy: 0.6658
# Epoch 30/40
# 157/157 [==============================] - 4s 26ms/step - loss: 1.0959 - accuracy: 0.6144 - val_loss: 0.9613 - val_accuracy: 0.6648
# Epoch 31/40
# 157/157 [==============================] - 4s 27ms/step - loss: 1.0846 - accuracy: 0.6212 - val_loss: 0.9516 - val_accuracy: 0.6655
# Epoch 32/40
# 157/157 [==============================] - 5s 32ms/step - loss: 1.0854 - accuracy: 0.6169 - val_loss: 0.9497 - val_accuracy: 0.6743
# Epoch 33/40
# 157/157 [==============================] - 5s 34ms/step - loss: 1.0791 - accuracy: 0.6176 - val_loss: 0.9458 - val_accuracy: 0.6735
# Epoch 34/40
# 157/157 [==============================] - 4s 27ms/step - loss: 1.0753 - accuracy: 0.6228 - val_loss: 0.9641 - val_accuracy: 0.6675
# Epoch 35/40
# 157/157 [==============================] - 4s 25ms/step - loss: 1.0720 - accuracy: 0.6229 - val_loss: 0.9640 - val_accuracy: 0.6652
# Epoch 36/40
# 157/157 [==============================] - 4s 27ms/step - loss: 1.0774 - accuracy: 0.6222 - val_loss: 0.9585 - val_accuracy: 0.6658
# Epoch 37/40
# 157/157 [==============================] - 4s 28ms/step - loss: 1.0723 - accuracy: 0.6207 - val_loss: 0.9540 - val_accuracy: 0.6671
# Epoch 38/40
# 157/157 [==============================] - 4s 26ms/step - loss: 1.0670 - accuracy: 0.6226 - val_loss: 0.9508 - val_accuracy: 0.6715
# Epoch 39/40
# 157/157 [==============================] - 4s 27ms/step - loss: 1.0676 - accuracy: 0.6249 - val_loss: 0.9478 - val_accuracy: 0.6725
# Epoch 40/40
# 157/157 [==============================] - 5s 33ms/step - loss: 1.0647 - accuracy: 0.6262 - val_loss: 0.9395 - val_accuracy: 0.6736

# %% [markdown]
# **Plot training and validation curves**

# %%
import matplotlib.pyplot as plt
# Assuming 'history' is the return value from model.fit()
history_dict = history.history

# Extracting loss and accuracy history
train_loss = history_dict['loss']
val_loss = history_dict['val_loss']
train_accuracy = history_dict['accuracy']
val_accuracy = history_dict['val_accuracy']

epochs = range(1, len(train_loss) + 1)

# Plotting training and validation loss
plt.figure(figsize=(14, 5))

# Training and validation loss plot
plt.subplot(1, 2, 1)
plt.plot(epochs, train_loss, 'bo-', label='Training Loss')
plt.plot(epochs, val_loss, 'ro-', label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Training and validation accuracy plot
plt.subplot(1, 2, 2)
plt.plot(epochs, train_accuracy, 'bo-', label='Training Accuracy')
plt.plot(epochs, val_accuracy, 'ro-', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()  # Adjusts the plots to ensure they don't overlap
plt.show()

# %%
def print_best_val_loss_and_accuracy(history):
    history_dict = history.history

    # Find the index of the best validation loss
    best_val_loss_index = np.argmin(history_dict['val_loss'])

    # Retrieve the best validation loss
    best_val_loss = history_dict['val_loss'][best_val_loss_index]

    # Retrieve the validation accuracy corresponding to the best validation loss
    best_val_accuracy = history_dict['val_accuracy'][best_val_loss_index]

    print(f"Best Validation Loss: {best_val_loss}")
    print(f"Validation Accuracy at Best Loss: {best_val_accuracy}")

# %%
print_best_val_loss_and_accuracy(history)
# Out:
# Best Validation Loss: 0.9394710659980774
# Validation Accuracy at Best Loss: 0.6736000180244446

# %%
best_model = keras.models.load_model("resnet50.keras", safe_mode=False)

test_loss, test_acc = best_model.evaluate(x_test, y_test)
print(f"Test accuracy: {test_acc}")
# Out:
# 313/313 [==============================] - 5s 8ms/step - loss: 0.9552 - accuracy: 0.6668
# Test accuracy: 0.6668000221252441

# %% [markdown]
# **Fine-tuning a pre-trained ResNet50**
#
# We we not able to beat a from-scratch approach using the frozen ResNet50. Let's unfreeze the last layer to see if it helps.

# %%
base_model = keras.applications.ResNet50(include_top=False,
                                         weights='imagenet',
                                         input_shape=(32, 32, 3))
base_model.trainable = False
# To unfreeze the last layer, we set its 'trainable' attribute to True
base_model.layers[-1].trainable = True

# Define the input tensor for your model
input_tensor = Input(shape=(32, 32, 3))

# Apply data augmentation to the inputs
x = data_augmentation(input_tensor)

# Apply the preprocess_input function
x = Lambda(preprocess_input)(x)

# Add custom layers on top of the base model
x = base_model(x)
x = GlobalAveragePooling2D()(x)
x = layers.Dense(256, activation='relu')(x)
x = layers.Dropout(0.5)(x)
predictions = Dense(10, activation='softmax')(x)

# Create the final model
model = Model(inputs=input_tensor, outputs=predictions)

# %%
model.compile(optimizer="adam", loss='categorical_crossentropy', metrics=['accuracy'])

# %%
callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="resnet50_finetune.keras",
        save_best_only=True,
        monitor="val_loss")
]

# %%
history = model.fit(x_train, y_train,
                    epochs=100,
                    batch_size=256,
                    validation_split=0.2,  # Use 20% of the data for validation
                    callbacks=callbacks,  # Include the callbacks in training
                    verbose=1)
# Out:
# Epoch 1/100
# 157/157 [==============================] - 5s 34ms/step - loss: 1.3056 - accuracy: 0.5383 - val_loss: 1.0576 - val_accuracy: 0.6325
# Epoch 2/100
# 157/157 [==============================] - 5s 32ms/step - loss: 1.2787 - accuracy: 0.5502 - val_loss: 1.0358 - val_accuracy: 0.6434
# Epoch 3/100
# 157/157 [==============================] - 4s 28ms/step - loss: 1.2532 - accuracy: 0.5619 - val_loss: 1.0373 - val_accuracy: 0.6415
# Epoch 4/100
# 157/157 [==============================] - 5s 34ms/step - loss: 1.2398 - accuracy: 0.5648 - val_loss: 1.0227 - val_accuracy: 0.6424
# Epoch 5/100
# 157/157 [==============================] - 5s 35ms/step - loss: 1.2183 - accuracy: 0.5723 - val_loss: 1.0179 - val_accuracy: 0.6463
# Epoch 6/100
# 157/157 [==============================] - 7s 42ms/step - loss: 1.2041 - accuracy: 0.5755 - val_loss: 1.0028 - val_accuracy: 0.6490
# Epoch 7/100
# 157/157 [==============================] - 5s 32ms/step - loss: 1.1883 - accuracy: 0.5822 - val_loss: 0.9980 - val_accuracy: 0.6483
# Epoch 8/100
# 157/157 [==============================] - 5s 34ms/step - loss: 1.1830 - accuracy: 0.5857 - val_loss: 0.9881 - val_accuracy: 0.6563
# Epoch 9/100
# 157/157 [==============================] - 5s 33ms/step - loss: 1.1724 - accuracy: 0.5876 - val_loss: 0.9847 - val_accuracy: 0.6527
# Epoch 10/100
# 157/157 [==============================] - 4s 25ms/step - loss: 1.1692 - accuracy: 0.5891 - val_loss: 0.9878 - val_accuracy: 0.6536
# Epoch 11/100
# 157/157 [==============================] - 5s 35ms/step - loss: 1.1573 - accuracy: 0.5943 - val_loss: 0.9842 - val_accuracy: 0.6566
# Epoch 12/100
# 157/157 [==============================] - 4s 26ms/step - loss: 1.1490 - accuracy: 0.5955 - val_loss: 0.9900 - val_accuracy: 0.6539
# Epoch 13/100
# 157/157 [==============================] - 5s 35ms/step - loss: 1.1498 - accuracy: 0.5962 - val_loss: 0.9712 - val_accuracy: 0.6614
# Epoch 14/100
# 157/157 [==============================] - 4s 26ms/step - loss: 1.1353 - accuracy: 0.5979 - val_loss: 0.9731 - val_accuracy: 0.6574
# Epoch 15/100
# 157/157 [==============================] - 4s 26ms/step - loss: 1.1360 - accuracy: 0.5986 - val_loss: 0.9756 - val_accuracy: 0.6545
# Epoch 16/100
# 157/157 [==============================] - 5s 35ms/step - loss: 1.1238 - accuracy: 0.6022 - val_loss: 0.9632 - val_accuracy: 0.6622
# Epoch 17/100
# 157/157 [==============================] - 4s 25ms/step - loss: 1.1272 - accuracy: 0.6047 - val_loss: 0.9641 - val_accuracy: 0.6624
# Epoch 18/100
# 157/157 [==============================] - 4s 25ms/step - loss: 1.1161 - accuracy: 0.6072 - val_loss: 0.9683 - val_accuracy: 0.6625
# Epoch 19/100
# 157/157 [==============================] - 4s 27ms/step - loss: 1.1282 - accuracy: 0.6053 - val_loss: 0.9825 - val_accuracy: 0.6594
# Epoch 20/100
# 157/157 [==============================] - 4s 25ms/step - loss: 1.1227 - accuracy: 0.6040 - val_loss: 0.9723 - val_accuracy: 0.6624
# Epoch 21/100
# 157/157 [==============================] - 4s 25ms/step - loss: 1.1057 - accuracy: 0.6100 - val_loss: 0.9745 - val_accuracy: 0.6640
# Epoch 22/100
# 157/157 [==============================] - 4s 27ms/step - loss: 1.1035 - accuracy: 0.6119 - val_loss: 0.9703 - val_accuracy: 0.6604
# Epoch 23/100
# 157/157 [==============================] - 5s 32ms/step - loss: 1.1049 - accuracy: 0.6129 - val_loss: 0.9624 - val_accuracy: 0.6632
# Epoch 24/100
# 157/157 [==============================] - 5s 35ms/step - loss: 1.1026 - accuracy: 0.6125 - val_loss: 0.9607 - val_accuracy: 0.6651
# Epoch 25/100
# 157/157 [==============================] - 4s 25ms/step - loss: 1.0934 - accuracy: 0.6146 - val_loss: 0.9700 - val_accuracy: 0.6629
# Epoch 26/100
# 157/157 [==============================] - 4s 25ms/step - loss: 1.0930 - accuracy: 0.6158 - val_loss: 0.9667 - val_accuracy: 0.6596
# Epoch 27/100
# 157/157 [==============================] - 4s 28ms/step - loss: 1.0888 - accuracy: 0.6158 - val_loss: 0.9637 - val_accuracy: 0.6638
# Epoch 28/100
# 157/157 [==============================] - 5s 35ms/step - loss: 1.0876 - accuracy: 0.6157 - val_loss: 0.9571 - val_accuracy: 0.6649
# Epoch 29/100
# 157/157 [==============================] - 4s 26ms/step - loss: 1.0921 - accuracy: 0.6151 - val_loss: 0.9607 - val_accuracy: 0.6619
# Epoch 30/100
# 157/157 [==============================] - 4s 28ms/step - loss: 1.0815 - accuracy: 0.6180 - val_loss: 0.9713 - val_accuracy: 0.6614
# Epoch 31/100
# 157/157 [==============================] - 5s 32ms/step - loss: 1.0776 - accuracy: 0.6177 - val_loss: 0.9484 - val_accuracy: 0.6673
# Epoch 32/100
# 157/157 [==============================] - 4s 27ms/step - loss: 1.0803 - accuracy: 0.6201 - val_loss: 0.9602 - val_accuracy: 0.6634
# Epoch 33/100
# 157/157 [==============================] - 4s 26ms/step - loss: 1.0739 - accuracy: 0.6234 - val_loss: 0.9588 - val_accuracy: 0.6678
# Epoch 34/100
# 157/157 [==============================] - 4s 26ms/step - loss: 1.0715 - accuracy: 0.6226 - val_loss: 0.9662 - val_accuracy: 0.6640
# Epoch 35/100
# 157/157 [==============================] - 4s 27ms/step - loss: 1.0676 - accuracy: 0.6224 - val_loss: 0.9508 - val_accuracy: 0.6667
# Epoch 36/100
# 157/157 [==============================] - 4s 26ms/step - loss: 1.0656 - accuracy: 0.6226 - val_loss: 0.9532 - val_accuracy: 0.6659
# Epoch 37/100
# 157/157 [==============================] - 4s 25ms/step - loss: 1.0619 - accuracy: 0.6269 - val_loss: 0.9517 - val_accuracy: 0.6675
# Epoch 38/100
# 157/157 [==============================] - 4s 27ms/step - loss: 1.0711 - accuracy: 0.6220 - val_loss: 0.9538 - val_accuracy: 0.6655
# Epoch 39/100
# 157/157 [==============================] - 4s 26ms/step - loss: 1.0605 - accuracy: 0.6271 - val_loss: 0.9594 - val_accuracy: 0.6650
# Epoch 40/100
# 157/157 [==============================] - 4s 26ms/step - loss: 1.0530 - accuracy: 0.6295 - val_loss: 0.9509 - val_accuracy: 0.6672
# Epoch 41/100
# 157/157 [==============================] - 5s 34ms/step - loss: 1.0538 - accuracy: 0.6266 - val_loss: 0.9481 - val_accuracy: 0.6709
# Epoch 42/100
# 157/157 [==============================] - 4s 26ms/step - loss: 1.0519 - accuracy: 0.6298 - val_loss: 0.9679 - val_accuracy: 0.6632
# Epoch 43/100
# 157/157 [==============================] - 4s 25ms/step - loss: 1.0589 - accuracy: 0.6278 - val_loss: 0.9607 - val_accuracy: 0.6718
# Epoch 44/100
# 157/157 [==============================] - 4s 28ms/step - loss: 1.0520 - accuracy: 0.6314 - val_loss: 0.9519 - val_accuracy: 0.6696
# Epoch 45/100
# 157/157 [==============================] - 4s 26ms/step - loss: 1.0478 - accuracy: 0.6279 - val_loss: 0.9596 - val_accuracy: 0.6689
# Epoch 46/100
# 157/157 [==============================] - 4s 26ms/step - loss: 1.0396 - accuracy: 0.6334 - val_loss: 0.9552 - val_accuracy: 0.6678
# Epoch 47/100
# 157/157 [==============================] - 4s 27ms/step - loss: 1.0466 - accuracy: 0.6310 - val_loss: 0.9582 - val_accuracy: 0.6699
# Epoch 48/100
# 157/157 [==============================] - 4s 26ms/step - loss: 1.0445 - accuracy: 0.6316 - val_loss: 0.9535 - val_accuracy: 0.6668
# Epoch 49/100
# 157/157 [==============================] - 4s 26ms/step - loss: 1.0410 - accuracy: 0.6330 - val_loss: 0.9546 - val_accuracy: 0.6680
# Epoch 50/100
# 157/157 [==============================] - 5s 33ms/step - loss: 1.0346 - accuracy: 0.6352 - val_loss: 0.9460 - val_accuracy: 0.6707
# Epoch 51/100
# 157/157 [==============================] - 4s 25ms/step - loss: 1.0441 - accuracy: 0.6317 - val_loss: 0.9513 - val_accuracy: 0.6741
# Epoch 52/100
# 157/157 [==============================] - 5s 34ms/step - loss: 1.0393 - accuracy: 0.6327 - val_loss: 0.9367 - val_accuracy: 0.6760
# Epoch 53/100
# 157/157 [==============================] - 4s 26ms/step - loss: 1.0356 - accuracy: 0.6324 - val_loss: 0.9575 - val_accuracy: 0.6700
# Epoch 54/100
# 157/157 [==============================] - 4s 26ms/step - loss: 1.0358 - accuracy: 0.6337 - val_loss: 0.9530 - val_accuracy: 0.6698
# Epoch 55/100
# 157/157 [==============================] - 4s 28ms/step - loss: 1.0320 - accuracy: 0.6348 - val_loss: 0.9450 - val_accuracy: 0.6708
# Epoch 56/100
# 157/157 [==============================] - 4s 26ms/step - loss: 1.0248 - accuracy: 0.6398 - val_loss: 0.9540 - val_accuracy: 0.6696
# Epoch 57/100
# 157/157 [==============================] - 4s 26ms/step - loss: 1.0298 - accuracy: 0.6349 - val_loss: 0.9526 - val_accuracy: 0.6743
# Epoch 58/100
# 157/157 [==============================] - 5s 29ms/step - loss: 1.0237 - accuracy: 0.6370 - val_loss: 0.9633 - val_accuracy: 0.6691
# Epoch 59/100
# 157/157 [==============================] - 4s 26ms/step - loss: 1.0308 - accuracy: 0.6392 - val_loss: 0.9455 - val_accuracy: 0.6699
# Epoch 60/100
# 157/157 [==============================] - 4s 26ms/step - loss: 1.0235 - accuracy: 0.6382 - val_loss: 0.9569 - val_accuracy: 0.6703
# Epoch 61/100
# 157/157 [==============================] - 4s 27ms/step - loss: 1.0216 - accuracy: 0.6366 - val_loss: 0.9579 - val_accuracy: 0.6722
# Epoch 62/100
# 157/157 [==============================] - 4s 26ms/step - loss: 1.0178 - accuracy: 0.6401 - val_loss: 0.9532 - val_accuracy: 0.6695
# Epoch 63/100
# 157/157 [==============================] - 4s 27ms/step - loss: 1.0192 - accuracy: 0.6385 - val_loss: 0.9496 - val_accuracy: 0.6747
# Epoch 64/100
# 157/157 [==============================] - 4s 26ms/step - loss: 1.0199 - accuracy: 0.6396 - val_loss: 0.9511 - val_accuracy: 0.6698
# Epoch 65/100
# 157/157 [==============================] - 4s 25ms/step - loss: 1.0189 - accuracy: 0.6382 - val_loss: 0.9434 - val_accuracy: 0.6721
# Epoch 66/100
# 157/157 [==============================] - 4s 27ms/step - loss: 1.0218 - accuracy: 0.6412 - val_loss: 0.9583 - val_accuracy: 0.6664
# Epoch 67/100
# 157/157 [==============================] - 4s 26ms/step - loss: 1.0154 - accuracy: 0.6418 - val_loss: 0.9504 - val_accuracy: 0.6694
# Epoch 68/100
# 157/157 [==============================] - 4s 26ms/step - loss: 1.0166 - accuracy: 0.6429 - val_loss: 0.9519 - val_accuracy: 0.6699
# Epoch 69/100
# 157/157 [==============================] - 4s 27ms/step - loss: 1.0156 - accuracy: 0.6421 - val_loss: 0.9590 - val_accuracy: 0.6668
# Epoch 70/100
# 157/157 [==============================] - 4s 26ms/step - loss: 1.0031 - accuracy: 0.6480 - val_loss: 0.9634 - val_accuracy: 0.6691
# Epoch 71/100
# 157/157 [==============================] - 4s 26ms/step - loss: 1.0105 - accuracy: 0.6448 - val_loss: 0.9560 - val_accuracy: 0.6707
# Epoch 72/100
# 157/157 [==============================] - 4s 27ms/step - loss: 1.0151 - accuracy: 0.6395 - val_loss: 0.9419 - val_accuracy: 0.6730
# Epoch 73/100
# 157/157 [==============================] - 4s 25ms/step - loss: 1.0027 - accuracy: 0.6470 - val_loss: 0.9609 - val_accuracy: 0.6675
# Epoch 74/100
# 157/157 [==============================] - 4s 25ms/step - loss: 1.0002 - accuracy: 0.6487 - val_loss: 0.9435 - val_accuracy: 0.6719
# Epoch 75/100
# 157/157 [==============================] - 4s 28ms/step - loss: 0.9945 - accuracy: 0.6487 - val_loss: 0.9398 - val_accuracy: 0.6778
# Epoch 76/100
# 157/157 [==============================] - 4s 26ms/step - loss: 0.9973 - accuracy: 0.6510 - val_loss: 0.9537 - val_accuracy: 0.6736
# Epoch 77/100
# 157/157 [==============================] - 4s 26ms/step - loss: 0.9946 - accuracy: 0.6511 - val_loss: 0.9481 - val_accuracy: 0.6733
# Epoch 78/100
# 157/157 [==============================] - 4s 28ms/step - loss: 1.0034 - accuracy: 0.6488 - val_loss: 0.9529 - val_accuracy: 0.6718
# Epoch 79/100
# 157/157 [==============================] - 4s 26ms/step - loss: 0.9944 - accuracy: 0.6507 - val_loss: 0.9472 - val_accuracy: 0.6759
# Epoch 80/100
# 157/157 [==============================] - 4s 25ms/step - loss: 0.9905 - accuracy: 0.6521 - val_loss: 0.9459 - val_accuracy: 0.6769
# Epoch 81/100
# 157/157 [==============================] - 4s 28ms/step - loss: 1.0060 - accuracy: 0.6478 - val_loss: 0.9495 - val_accuracy: 0.6702
# Epoch 82/100
# 157/157 [==============================] - 4s 25ms/step - loss: 0.9964 - accuracy: 0.6512 - val_loss: 0.9578 - val_accuracy: 0.6707
# Epoch 83/100
# 157/157 [==============================] - 4s 25ms/step - loss: 0.9989 - accuracy: 0.6498 - val_loss: 0.9549 - val_accuracy: 0.6685
# Epoch 84/100
# 157/157 [==============================] - 4s 27ms/step - loss: 0.9960 - accuracy: 0.6470 - val_loss: 0.9573 - val_accuracy: 0.6700
# Epoch 85/100
# 157/157 [==============================] - 4s 26ms/step - loss: 0.9946 - accuracy: 0.6508 - val_loss: 0.9452 - val_accuracy: 0.6733
# Epoch 86/100
# 157/157 [==============================] - 5s 35ms/step - loss: 0.9927 - accuracy: 0.6502 - val_loss: 0.9359 - val_accuracy: 0.6754
# Epoch 87/100
# 157/157 [==============================] - 4s 27ms/step - loss: 0.9934 - accuracy: 0.6482 - val_loss: 0.9396 - val_accuracy: 0.6801
# Epoch 88/100
# 157/157 [==============================] - 4s 26ms/step - loss: 0.9921 - accuracy: 0.6496 - val_loss: 0.9481 - val_accuracy: 0.6720
# Epoch 89/100
# 157/157 [==============================] - 4s 27ms/step - loss: 0.9923 - accuracy: 0.6508 - val_loss: 0.9426 - val_accuracy: 0.6777
# Epoch 90/100
# 157/157 [==============================] - 4s 26ms/step - loss: 0.9859 - accuracy: 0.6520 - val_loss: 0.9478 - val_accuracy: 0.6763
# Epoch 91/100
# 157/157 [==============================] - 4s 25ms/step - loss: 0.9986 - accuracy: 0.6471 - val_loss: 0.9520 - val_accuracy: 0.6730
# Epoch 92/100
# 157/157 [==============================] - 4s 26ms/step - loss: 0.9895 - accuracy: 0.6507 - val_loss: 0.9381 - val_accuracy: 0.6747
# Epoch 93/100
# 157/157 [==============================] - 4s 27ms/step - loss: 0.9823 - accuracy: 0.6551 - val_loss: 0.9460 - val_accuracy: 0.6731
# Epoch 94/100
# 157/157 [==============================] - 4s 26ms/step - loss: 0.9907 - accuracy: 0.6486 - val_loss: 0.9498 - val_accuracy: 0.6728
# Epoch 95/100
# 157/157 [==============================] - 4s 27ms/step - loss: 0.9830 - accuracy: 0.6524 - val_loss: 0.9691 - val_accuracy: 0.6675
# Epoch 96/100
# 157/157 [==============================] - 4s 25ms/step - loss: 0.9852 - accuracy: 0.6529 - val_loss: 0.9452 - val_accuracy: 0.6749
# Epoch 97/100
# 157/157 [==============================] - 4s 25ms/step - loss: 0.9835 - accuracy: 0.6538 - val_loss: 0.9609 - val_accuracy: 0.6700
# Epoch 98/100
# 157/157 [==============================] - 4s 27ms/step - loss: 0.9854 - accuracy: 0.6532 - val_loss: 0.9533 - val_accuracy: 0.6695
# Epoch 99/100
# 157/157 [==============================] - 4s 25ms/step - loss: 0.9768 - accuracy: 0.6539 - val_loss: 0.9526 - val_accuracy: 0.6718
# Epoch 100/100
# 157/157 [==============================] - 4s 26ms/step - loss: 0.9812 - accuracy: 0.6537 - val_loss: 0.9563 - val_accuracy: 0.6709

# %%
print_best_val_loss_and_accuracy(history)
# Out:
# Best Validation Loss: 0.9358782172203064
# Validation Accuracy at Best Loss: 0.6754000186920166

# %%
# Assuming 'history' is the return value from model.fit()
history_dict = history.history

# Extracting loss and accuracy history
train_loss = history_dict['loss']
val_loss = history_dict['val_loss']
train_accuracy = history_dict['accuracy']
val_accuracy = history_dict['val_accuracy']

epochs = range(1, len(train_loss) + 1)

# Plotting training and validation loss
plt.figure(figsize=(14, 5))

# Training and validation loss plot
plt.subplot(1, 2, 1)
plt.plot(epochs, train_loss, 'bo-', label='Training Loss')
plt.plot(epochs, val_loss, 'ro-', label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Training and validation accuracy plot
plt.subplot(1, 2, 2)
plt.plot(epochs, train_accuracy, 'bo-', label='Training Accuracy')
plt.plot(epochs, val_accuracy, 'ro-', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()  # Adjusts the plots to ensure they don't overlap
plt.show()

# %%
best_model = keras.models.load_model("resnet50_finetune.keras", safe_mode=False)

test_loss, test_acc = best_model.evaluate(x_test, y_test)
print(f"Test accuracy: {test_acc}")
# Out:
# 313/313 [==============================] - 5s 8ms/step - loss: 0.9519 - accuracy: 0.6674
# Test accuracy: 0.6674000024795532

# %% [markdown]
# **Conclusion**
#
# We were not able to beat the from-scratch approach despite having adjusted the weights in the last layer and running for twice the number of epochs. What are the ways forward? Here are a couple of suggestions:
#
# *   **Unfreeze more layers**. Fine-tuning more layers may allow the pretrained network to better adapt to the specifics of the dataset.
#
# *   **Advanced Data Augmentation**: Explore more sophisticated data augmentation techniques. Sometimes, introducing variations in the augmentation can help the model generalize better.
#
# *   **Try a different pre-trained model**. The problem might be ResNet50 itself. Keras includes many different pre-trained models. See here for a [list](https://keras.io/api/applications/).
